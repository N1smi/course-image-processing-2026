# %%
#1

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import copy

# %%
image = cv2.imread('img.jpg')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(image_gray, cmap="gray")

# %%
# Gaussian noise
mean = 0
stddev = 100
noise_gauss = np.zeros(image_gray.shape, np.uint8)
cv2.randn(noise_gauss, mean, stddev)
# Out:
# array([[  0, 144,  72, ..., 142,   0,  76],
#        [  0,   0, 156, ...,   0,   0,   0],
#        [  0, 114,  41, ...,  15,  77, 131],
#        ...,
#        [  0,  10,   0, ...,   0,   0,   0],
#        [177,   0,   0, ...,  95, 101,   0],
#        [  0,   7,  74, ..., 150,   0,   0]],
#       shape=(4000, 6000), dtype=uint8)

# %%
image_noise_gauss = cv2.add(image_gray, noise_gauss)

# %%
plt.imshow(image_noise_gauss, cmap="gray")

# %%
from skimage.metrics import structural_similarity, mean_squared_error
mse_gauss = mean_squared_error(image_gray, image_noise_gauss)
rmse_gauss = np.sqrt(mse_gauss)
ssim_gauss = structural_similarity(image_gray, image_noise_gauss)
print(f"SSIM: {ssim_gauss} RMSE: {rmse_gauss}")
# Out:
# SSIM: 0.025934800125574472 RMSE: 67.04452664212543

# %%
# Salt and pepper
noise_sp =  np.random.randint(0, 11, size = (image_gray.shape[0], image_gray.shape[1]), dtype=int)
zeros_pixel = np.where(noise_sp == 0)
ones_pixel = np.where(noise_sp == 10)

# %%
image_noise_sp = copy.deepcopy(image_gray)

# %%
image_noise_sp[zeros_pixel] = 0
image_noise_sp[ones_pixel] = 255

# %%
plt.imshow(image_noise_sp, cmap="gray")

# %%
mse_sp = mean_squared_error(image_gray, image_noise_sp)
rmse_sp = np.sqrt(mse_sp)
ssim_sp = structural_similarity(image_gray, image_noise_sp)
print(f"SSIM: {ssim_sp} RMSE: {rmse_sp}")
# Out:
# SSIM: 0.027456281022433457 RMSE: 63.97806328376678

# %%
#2

# %%
#Median filter

# %%
image_sp_median = cv2.medianBlur(image_noise_sp, 3)

# %%
mse_sp_median = mean_squared_error(image_gray, image_sp_median)
rmse_sp_median = np.sqrt(mse_sp_median)
ssim_sp_median = structural_similarity(image_gray, image_sp_median)
print(f"SSIM: {ssim_sp:.2f} -> {ssim_sp_median:.2f} RMSE: {rmse_sp:.2f} -> {rmse_sp_median:.2f}")
# Out:
# SSIM: 0.03 -> 0.88 RMSE: 63.98 -> 5.91

# %%
plt.imshow(image_sp_median, cmap="gray")

# %%
image_gauss_median = cv2.medianBlur(image_noise_gauss, 3)

# %%
mse_gauss_median = mean_squared_error(image_gray, image_gauss_median)
rmse_gauss_median = np.sqrt(mse_gauss_median)
ssim_gauss_median = structural_similarity(image_gray, image_gauss_median)
print(f"SSIM: {ssim_gauss:.2f} -> {ssim_gauss_median:.2f} RMSE: {rmse_gauss:.2f} -> {rmse_gauss_median:.2f}")
# Out:
# SSIM: 0.03 -> 0.15 RMSE: 67.04 -> 29.03

# %%
plt.imshow(image_gauss_median, cmap="gray")

# %%
image_sp_median_up = cv2.medianBlur(image_noise_sp, 5)

# %%
mse_sp_median_up = mean_squared_error(image_gray, image_sp_median_up)
rmse_sp_median_up = np.sqrt(mse_sp_median_up)
ssim_sp_median_up = structural_similarity(image_gray, image_sp_median_up)
print(f"SSIM: {ssim_sp_median:.2f} -> {ssim_sp_median_up:.2f} RMSE: {rmse_sp_median:.2f} -> {rmse_sp_median_up:.2f}")
# Out:
# SSIM: 0.88 -> 0.85 RMSE: 5.91 -> 3.54

# %%
#Gaussian filter

# %%
image_gauss_gauss = cv2.GaussianBlur(image_noise_gauss, (5,5), 0)

# %%
mse_gauss_gauss = mean_squared_error(image_gray, image_gauss_gauss)
rmse_gauss_gauss = np.sqrt(mse_gauss_gauss)
ssim_gauss_gauss = structural_similarity(image_gray, image_gauss_gauss)
print(f"SSIM: {ssim_gauss:.2f} -> {ssim_gauss_gauss:.2f} RMSE: {rmse_gauss:.2f} -> {rmse_gauss_gauss:.2f}")
# Out:
# SSIM: 0.03 -> 0.23 RMSE: 67.04 -> 41.57

# %%
plt.imshow(image_gauss_gauss, cmap="gray")

# %%
image_sp_gauss = cv2.GaussianBlur(image_noise_sp, (5,5), 0)

# %%
mse_sp_gauss = mean_squared_error(image_gray, image_sp_gauss)
rmse_sp_gauss = np.sqrt(mse_sp_gauss)
ssim_sp_gauss = structural_similarity(image_gray, image_sp_gauss)
print(f"SSIM: {ssim_sp:.2f} -> {ssim_sp_gauss:.2f} RMSE: {rmse_sp:.2f} -> {rmse_sp_gauss:.2f}")
# Out:
# SSIM: 0.03 -> 0.23 RMSE: 63.98 -> 22.50

# %%
plt.imshow(image_sp_gauss, cmap="gray")

# %%
image_gauss_gauss_up = cv2.GaussianBlur(image_noise_gauss, (9,9), 0)

# %%
mse_gauss_gauss_up = mean_squared_error(image_gray, image_gauss_gauss_up)
rmse_gauss_gauss_up = np.sqrt(mse_gauss_gauss_up)
ssim_gauss_gauss_up = structural_similarity(image_gray, image_gauss_gauss_up)
print(f"SSIM: {ssim_gauss_gauss:.2f} -> {ssim_gauss_gauss_up:.2f} RMSE: {rmse_gauss_gauss:.2f} -> {rmse_gauss_gauss_up:.2f}")
# Out:
# SSIM: 0.23 -> 0.42 RMSE: 41.57 -> 39.88

# %%
#Bilateral filter

# %%
image_gauss_bilateral = cv2.bilateralFilter(image_noise_gauss, d=9, sigmaColor=75, sigmaSpace=75)

# %%
mse_gauss_bilateral = mean_squared_error(image_gray, image_gauss_bilateral)
rmse_gauss_bilateral = np.sqrt(mse_gauss_bilateral)
ssim_gauss_bilateral = structural_similarity(image_gray, image_gauss_bilateral)
print(f"SSIM: {ssim_gauss:.2f} -> {ssim_gauss_bilateral:.2f} RMSE: {rmse_gauss:.2f} -> {rmse_gauss_bilateral:.2f}\n")
# Out:
# SSIM: 0.03 -> 0.10 RMSE: 67.04 -> 42.24

# %%
plt.imshow(image_gauss_bilateral, cmap="gray")

# %%
image_sp_bilateral = cv2.bilateralFilter(image_noise_sp, d=9, sigmaColor=75, sigmaSpace=75)

# %%
mse_sp_bilateral = mean_squared_error(image_gray, image_sp_bilateral)
rmse_sp_bilateral = np.sqrt(mse_sp_bilateral)
ssim_sp_bilateral = structural_similarity(image_gray, image_sp_bilateral)
print(f"SSIM: {ssim_sp:.2f} -> {ssim_sp_bilateral:.2f} RMSE: {rmse_sp:.2f} -> {rmse_sp_bilateral:.2f}")
# Out:
# SSIM: 0.03 -> 0.06 RMSE: 63.98 -> 51.42

# %%
plt.imshow(image_sp_bilateral, cmap="gray")

# %%
image_gauss_bilateral_up = cv2.bilateralFilter(image_noise_gauss, d=15, sigmaColor=150, sigmaSpace=150)

# %%
mse_gauss_bilateral_up = mean_squared_error(image_gray, image_gauss_bilateral_up)
rmse_gauss_bilateral_up = np.sqrt(mse_gauss_bilateral_up)
ssim_gauss_bilateral_up = structural_similarity(image_gray, image_gauss_bilateral_up)
print(f"SSIM: {ssim_gauss_bilateral:.2f} -> {ssim_gauss_bilateral_up:.2f} RMSE: {rmse_gauss_bilateral:.2f} -> {rmse_gauss_bilateral_up:.2f}")
# Out:
# SSIM: 0.10 -> 0.42 RMSE: 42.24 -> 36.18

# %%
#Non‑local mean filter

# %%
image_gauss_nl = cv2.fastNlMeansDenoising(image_noise_gauss, None, h=60, templateWindowSize=7, searchWindowSize=21)

# %%
mse_gauss_nl = mean_squared_error(image_gray, image_gauss_nl)
rmse_gauss_nl = np.sqrt(mse_gauss_nl)
ssim_gauss_nl = structural_similarity(image_gray, image_gauss_nl)

print(f"SSIM: {ssim_gauss:.2f} -> {ssim_gauss_nl:.2f} RMSE: {rmse_gauss:.2f} -> {rmse_gauss_nl:.2f}")
# Out:
# SSIM: 0.03 -> 0.61 RMSE: 67.04 -> 38.01

# %%
plt.imshow(image_gauss_nl, cmap="gray")

# %%
image_sp_nl = cv2.fastNlMeansDenoising(image_noise_sp, None, h=60, templateWindowSize=7, searchWindowSize=21)

# %%
mse_sp_nl = mean_squared_error(image_gray, image_sp_nl)
rmse_sp_nl = np.sqrt(mse_sp_nl)
ssim_sp_nl = structural_similarity(image_gray, image_sp_nl)

# %%
print(f"SSIM: {ssim_sp:.2f} -> {ssim_sp_nl:.2f} RMSE: {rmse_sp:.2f} -> {rmse_sp_nl:.2f}")
# Out:
# SSIM: 0.03 -> 0.63 RMSE: 63.98 -> 13.55

# %%
plt.imshow(image_sp_nl, cmap="gray")

# %%
image_gauss_nl_high = cv2.fastNlMeansDenoising(image_noise_gauss, None, h=80, templateWindowSize=7, searchWindowSize=21)

# %%
mse_gauss_nl_high = mean_squared_error(image_gray, image_gauss_nl_high)
rmse_gauss_nl_high = np.sqrt(mse_gauss_nl_high)
ssim_gauss_nl_high = structural_similarity(image_gray, image_gauss_nl_high)

print(f"SSIM: {ssim_gauss_nl:.2f} -> {ssim_gauss_nl_high:.2f} RMSE: {rmse_gauss_nl:.2f} -> {rmse_gauss_nl_high:.2f}")
# Out:
# SSIM: 0.61 -> 0.64 RMSE: 38.01 -> 38.38

# %%
import pandas as pd


data = [
    # 1. MEDIAN FILTER
    {
        "Noise Type": "Salt & Pepper",
        "Filter": "Median Filter",
        "Parameters": "kernel=3",
        "SSIM": 0.88,
        "RMSE": 5.91,
    },
    {
        "Noise Type": "Salt & Pepper",
        "Filter": "Median Filter",
        "Parameters": "kernel=5",
        "SSIM": 0.85,
        "RMSE": 3.54,
    },
    {
        "Noise Type": "Gaussian",
        "Filter": "Median Filter",
        "Parameters": "kernel=3",
        "SSIM": 0.15,
        "RMSE": 29.03,
    },


    # 2. GAUSSIAN BLUR
    {
        "Noise Type": "Gaussian",
        "Filter": "Gaussian Blur",
        "Parameters": "kernel=(5, 5)",
        "SSIM": 0.23,
        "RMSE": 41.57,
    },
    {
        "Noise Type": "Gaussian",
        "Filter": "Gaussian Blur",
        "Parameters": "kernel=(9, 9)",
        "SSIM": 0.42,
        "RMSE": 39.88,
    },
    {
        "Noise Type": "Salt & Pepper",
        "Filter": "Gaussian Blur",
        "Parameters": "kernel=(5, 5)",
        "SSIM": 0.23,
        "RMSE": 22.50,
    },


    # 3. BILATERAL FILTER
    {
        "Noise Type": "Gaussian",
        "Filter": "Bilateral Filter",
        "Parameters": "d=9, sColor=75, sSpace=75",
        "SSIM": 0.10,
        "RMSE": 42.24,
    },
    {
        "Noise Type": "Gaussian",
        "Filter": "Bilateral Filter",
        "Parameters": "d=15, sColor=150, sSpace=150",
        "SSIM": 0.42,
        "RMSE": 36.18,
    },
    {
        "Noise Type": "Salt & Pepper",
        "Filter": "Bilateral Filter",
        "Parameters": "d=9, sColor=75, sSpace=75",
        "SSIM": 0.06,
        "RMSE": 51.42,
    },


    # 4. NON-LOCAL MEANS FILTER
    {
        "Noise Type": "Gaussian",
        "Filter": "Non-Local Means",
        "Parameters": "h=60, template=7, search=21",
        "SSIM": 0.61,
        "RMSE": 38.01,
    },
    {
        "Noise Type": "Gaussian",
        "Filter": "Non-Local Means",
        "Parameters": "h=80, template=7, search=21",
        "SSIM": 0.64,
        "RMSE": 38.38,
    },
    {
        "Noise Type": "Salt & Pepper",
        "Filter": "Non-Local Means",
        "Parameters": "h=60, template=7, search=21",
        "SSIM": 0.63,
        "RMSE": 13.55,
    }
]

df_results = pd.DataFrame(data)
display(df_results)
# Out:
#        Noise Type            Filter                    Parameters  SSIM   RMSE
# 0   Salt & Pepper     Median Filter                      kernel=3  0.88   5.91
# 1   Salt & Pepper     Median Filter                      kernel=5  0.85   3.54
# 2        Gaussian     Median Filter                      kernel=3  0.15  29.03
# 3        Gaussian     Gaussian Blur                 kernel=(5, 5)  0.23  41.57
# 4        Gaussian     Gaussian Blur                 kernel=(9, 9)  0.42  39.88
# 5   Salt & Pepper     Gaussian Blur                 kernel=(5, 5)  0.23  22.50
# 6        Gaussian  Bilateral Filter     d=9, sColor=75, sSpace=75  0.10  42.24
# 7        Gaussian  Bilateral Filter  d=15, sColor=150, sSpace=150  0.42  36.18
# 8   Salt & Pepper  Bilateral Filter     d=9, sColor=75, sSpace=75  0.06  51.42
# 9        Gaussian   Non-Local Means   h=60, template=7, search=21  0.61  38.01
# 10       Gaussian   Non-Local Means   h=80, template=7, search=21  0.64  38.38
# 11  Salt & Pepper   Non-Local Means   h=60, template=7, search=21  0.63  13.55

# %%
# The best result for Gaussian noise filtering is Non-Local Means
# The best result for constant noise filtering is Median Filter
